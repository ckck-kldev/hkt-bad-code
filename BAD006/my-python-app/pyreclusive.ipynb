# %%
import os

def find_py_files(directory):
    for root, dirs, files in os.walk(directory):
        for file in files:
            if file.endswith('.py'):
                print(os.path.join(root, file))

# Example usage
find_py_files('./')
# Out:
# ./test.py
# ./.venv/lib/python3.9/site-packages/six.py
# ./.venv/lib/python3.9/site-packages/panda/models.py
# ./.venv/lib/python3.9/site-packages/panda/request.py
# ./.venv/lib/python3.9/site-packages/panda/__init__.py
# ./.venv/lib/python3.9/site-packages/panda/test.py
# ./.venv/lib/python3.9/site-packages/panda/upload_session.py
# ./.venv/lib/python3.9/site-packages/tzdata/__init__.py
# ./.venv/lib/python3.9/site-packages/tzdata/zoneinfo/__init__.py
# ./.venv/lib/python3.9/site-packages/tzdata/zoneinfo/Indian/__init__.py
# ./.venv/lib/python3.9/site-packages/tzdata/zoneinfo/Atlantic/__init__.py
# ./.venv/lib/python3.9/site-packages/tzdata/zoneinfo/US/__init__.py
# ./.venv/lib/python3.9/site-packages/tzdata/zoneinfo/Brazil/__init__.py
# ./.venv/lib/python3.9/site-packages/tzdata/zoneinfo/Pacific/__init__.py
# ./.venv/lib/python3.9/site-packages/tzdata/zoneinfo/Arctic/__init__.py
# ./.venv/lib/python3.9/site-packages/tzdata/zoneinfo/America/__init__.py
# ...
